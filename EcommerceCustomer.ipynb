# %%
#import libraries

install.packages("ggplot2")
install.packages("tidyverse")
install.packages("dplyr")
install.packages("readr")
install.packages("hexbin")
install.packages("caret")
# Out:
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# package 'dplyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# package 'readr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# package 'hexbin' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# package 'caret' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages

# %%
library(readr)
library(tidyverse)
library(dplyr)
library(ggplot2)
library(hexbin)
library(caret)
# Out:
# Warning message:
# "package 'readr' was built under R version 3.6.3"Warning message:
# "package 'tidyverse' was built under R version 3.6.3"-- Attaching packages --------------------------------------- tidyverse 1.3.0 --
# v ggplot2 3.3.3     v dplyr   1.0.5
# v tibble  3.1.0     v stringr 1.4.0
# v tidyr   1.1.3     v forcats 0.4.0
# v purrr   0.3.4
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Warning message:
# "package 'hexbin' was built under R version 3.6.3"Warning message:
# "package 'caret' was built under R version 3.6.3"Loading required package: lattice
#
# Attaching package: 'caret'
#
# The following object is masked from 'package:purrr':
#
#     lift

# %%
#Import data
customers <- read.csv("D:/DATA CAMP PROJECTS/Ecommerce Customers/Ecommerce Customers.csv")

# %%
#Check the head,str and summary of the customers 
head(customers)
glimpse(customers)
summary(customers)
str(customers)
# Out:
#   Email
# 1 mstephenson@fernandez.com
# 2 hduke@hotmail.com
# 3 pallen@yahoo.com
# 4 riverarebecca@gmail.com
# 5 mstephens@davidson-herman.com
# 6 alvareznancy@lucas.biz
#   Address                                                    Avatar
# 1 835 Frank Tunnel\nWrightmouth, MI 82180-9605               Violet
# 2 4547 Archer Common\nDiazchester, CA 06566-8576             DarkGreen
# 3 24645 Valerie Unions Suite 582\nCobbborough, DC 99414-7564 Bisque
# 4 1414 David Throughway\nPort Jason, OH 22070-1220           SaddleBrown
# 5 14023 Rodriguez Passage\nPort Jacobville, PR 37242-1057    MediumAquaMarine
# 6 645 Martha Park Apt. 611\nJeffreychester, MN 67218-7250    FloralWhite
#   Avg..Session.Length Time.on.App Time.on.Website Length.of.Membership
# 1 34.49727            12.65565    39.57767        4.082621
# 2 31.92627            11.10946    37.26896        2.664034
# 3 33.00091            11.33028    37.11060        4.104543
# 4 34.30556            13.71751    36.72128        3.120179
# 5 33.33067            12.79519    37.53665        4.446308
# 6 33.87104            12.02693    34.47688        5.493507
#   Yearly.Amount.Spent
# 1 587.9511
# 2 392.2049
# 3 487.5475
# 4 581.8523
# 5 599.4061
# 6 637.1024
# Rows: 500
# Columns: 8
# $ Email                <fct> mstephenson@fernandez.com, hduke@hotmail.com, pal~
# $ Address              <fct> "835 Frank Tunnel\nWrightmouth, MI 82180-9605", "~
# $ Avatar               <fct> Violet, DarkGreen, Bisque, SaddleBrown, MediumAqu~
# $ Avg..Session.Length  <dbl> 34.49727, 31.92627, 33.00091, 34.30556, 33.33067,~
# $ Time.on.App          <dbl> 12.65565, 11.10946, 11.33028, 13.71751, 12.79519,~
# $ Time.on.Website      <dbl> 39.57767, 37.26896, 37.11060, 36.72128, 37.53665,~
# $ Length.of.Membership <dbl> 4.082621, 2.664034, 4.104543, 3.120179, 4.446308,~
# $ Yearly.Amount.Spent  <dbl> 587.9511, 392.2049, 487.5475, 581.8523, 599.4061,~
#                               Email
#  aaron04@yahoo.com               :  1
#  aaron11@luna.com                :  1
#  aaron22@gmail.com               :  1
#  aaron89@gmail.com               :  1
#  acampbell@sanchez-velasquez.info:  1
#  acontreras@hotmail.com          :  1
#  (Other)                         :494
#                                                         Address
#  0001 Mack Mill\nNorth Jennifer, NE 42021-5936               :  1
#  001 Estrada Union\nLewismouth, TN 47360                     :  1
#  0013 Andre Field\nWhitebury, AZ 68447-6306                  :  1
#  0030 Mathis Square Suite 154\nSouth Jadehaven, AR 33997-4450:  1
#  00615 Tracy Islands\nNew Marcfort, MO 87297-7431            :  1
#  01242 Stephanie Ways Suite 003\nChurchville, MO 35617       :  1
#  (Other)                                                     :494
#          Avatar    Avg..Session.Length  Time.on.App     Time.on.Website
#  CadetBlue  :  7   Min.   :29.53       Min.   : 8.508   Min.   :33.91
#  Cyan       :  7   1st Qu.:32.34       1st Qu.:11.388   1st Qu.:36.35
#  GreenYellow:  7   Median :33.08       Median :11.983   Median :37.07
#  SlateBlue  :  7   Mean   :33.05       Mean   :12.052   Mean   :37.06
#  Teal       :  7   3rd Qu.:33.71       3rd Qu.:12.754   3rd Qu.:37.72
#  Aqua       :  6   Max.   :36.14       Max.   :15.127   Max.   :40.01
#  (Other)    :459
#  Length.of.Membership Yearly.Amount.Spent
#  Min.   :0.2699       Min.   :256.7
#  1st Qu.:2.9304       1st Qu.:445.0
#  Median :3.5340       Median :498.9
#  Mean   :3.5335       Mean   :499.3
#  3rd Qu.:4.1265       3rd Qu.:549.3
#  Max.   :6.9227       Max.   :765.5
# 'data.frame':	500 obs. of  8 variables:
#  $ Email               : Factor w/ 500 levels "aaron04@yahoo.com",..: 343 191 356 392 342 18 260 44 461 57 ...
#  $ Address             : Factor w/ 500 levels "0001 Mack Mill\nNorth Jennifer, NE 42021-5936",..: 382 227 124 63 61 314 329 483 392 460 ...
#  $ Avatar              : Factor w/ 138 levels "AliceBlue","AntiqueWhite",..: 133 26 7 115 81 44 35 3 116 12 ...
#  $ Avg..Session.Length : num  34.5 31.9 33 34.3 33.3 ...
#  $ Time.on.App         : num  12.7 11.1 11.3 13.7 12.8 ...
#  $ Time.on.Website     : num  39.6 37.3 37.1 36.7 37.5 ...
#  $ Length.of.Membership: num  4.08 2.66 4.1 3.12 4.45 ...
#  $ Yearly.Amount.Spent : num  588 392 488 582 599 ...

# %%
#Exploratory Data Analysis
ggplot(customers,aes(x = Time.on.Website, y = Yearly.Amount.Spent)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
#Do the same but with the Time on App column instead
ggplot(customers,aes(x = Time.on.App, y = Yearly.Amount.Spent)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
#create a hex bin plot comparing Time on App and Length of Membership
ggplot(customers,aes(x = Time.on.App, y = Yearly.Amount.Spent)) + geom_hex(bins =30)
# Out:
# plot without title

# %%
#Only keep numeric variables
NumCol <- sapply(customers,is.numeric)
Ecom_cust <- customers[,NumCol]

# %%
#From the below diagram we can see 'Yearly Amount Spent' is highly correlated with 'Lenght of Membership'

install.packages("psych")
library(psych)
pairs.panels(Ecom_cust[,1:5],
            method = "pearson",
            hist.col = "#66A61E",
            density = TRUE,
            ellipses = TRUE)
# Out:
# also installing the dependencies 'tmvnsim', 'mnormt'
# package 'tmvnsim' successfully unpacked and MD5 sums checked
# package 'mnormt' successfully unpacked and MD5 sums checked
# package 'psych' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# Warning message:
# "package 'psych' was built under R version 3.6.3"
# Attaching package: 'psych'
#
# The following objects are masked from 'package:ggplot2':
#
#     %+%, alpha
# plot without title

# %%
# Create a linear model plot of Yearly Amount Spent vs. Length of Membership
ggplot(customers,aes(x = Length.of.Membership, y = Yearly.Amount.Spent)) + geom_point() + geom_smooth(method = lm)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
#Training and Testing Data
#let's go ahead and split the data into training and testing sets. Set a variable X equal to the numerical features of the customers and a variable y equal to the "Yearly Amount Spent" column

install.packages("caTools")
library(caTools)
set.seed(101)
sample <- sample.split(Ecom_cust$Yearly.Amount.Spent, SplitRatio = 0.7)
train <- subset(Ecom_cust,sample = TRUE)
# Out:
# also installing the dependency 'bitops'
# package 'bitops' successfully unpacked and MD5 sums checked
# package 'caTools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Bhavin\AppData\Local\Temp\RtmpQHc1Fu\downloaded_packages
# Warning message:
# "package 'caTools' was built under R version 3.6.3"

# %%
#Training the Model
#Train model on our training data
model <- lm(Yearly.Amount.Spent~., data = train)
summary(model)
# Out:
# Call:
# lm(formula = Yearly.Amount.Spent ~ ., data = train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -30.4059  -6.2191  -0.1364   6.6048  30.3085
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -1051.5943    22.9925 -45.736   <2e-16 ***
# Avg..Session.Length     25.7343     0.4510  57.057   <2e-16 ***
# Time.on.App             38.7092     0.4510  85.828   <2e-16 ***
# Time.on.Website          0.4367     0.4441   0.983    0.326
# Length.of.Membership    61.5773     0.4483 137.346   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 9.973 on 495 degrees of freedom
# Multiple R-squared:  0.9843,	Adjusted R-squared:  0.9842
# F-statistic:  7766 on 4 and 495 DF,  p-value: < 2.2e-16

# %%
#regression diagnostics
plot(model,which=1, col=c("red"))
# Out:
# Plot with title ""

# %%
#regression diagnostics
plot(model, which=2, col=c("blue"))
# Out:
# Plot with title ""

# %%
#Residuals
ggplot(Ecom_cust, aes(model$residuals)) + geom_histogram(fill = 'steelblue', color= 'black')
+ labs(title = "Histogram of Residuals", x = "residuals", y = "count")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Error in +labs(title = "Histogram of Residuals", x = "residuals", y = "count"): invalid argument to unary operator
# Traceback:
# plot without title

# %%
#Conclusion

#We still want to figure out the answer to the original question,
#do we have to focus our effort on mobile app or website development? 
#Or maybe that doesn't even really matter, and Membership Time is what is really important.
#Let's see if we can interpret the coefficients at all to get an idea.

# %%
#Print out the coefficients of the model
confint(model)
summary(model)$coef
# Out:
#                      2.5 %         97.5 %
# (Intercept)          -1096.7692602 -1006.41925
# Avg..Session.Length     24.8481081    26.62043
# Time.on.App             37.8230294    39.59528
# Time.on.Website         -0.4358024     1.30928
# Length.of.Membership    60.6964468    62.45820
#                      Estimate      Std. Error t value     Pr(>|t|)
# (Intercept)          -1051.5942553 22.9925391 -45.7363256 7.175244e-180
# Avg..Session.Length     25.7342711  0.4510268  57.0570802 8.174101e-220
# Time.on.App             38.7091538  0.4510072  85.8282471 2.217386e-299
# Time.on.Website          0.4367388  0.4440938   0.9834384  3.258722e-01
# Length.of.Membership    61.5773238  0.4483364 137.3462519  0.000000e+00

# %%
#How can you interpret these coefficients?

#Holding all other features fixed, a 1 unit increase in Avg. Session Length is associated with an increase of 25.73 total dollars spent.
#Holding all other features fixed, a 1 unit increase in Time on App is associated with an increase of 38.71 total dollars spent.
#Holding all other features fixed, a 1 unit increase in Time on Website is associated with an increase of 0.44 total dollars spent.
#Holding all other features fixed, a 1 unit increase in Length of Membership is associated with an increase of 61.58 total dollars spent.
